# %% [markdown]
# <a href="https://colab.research.google.com/github/laurengray42/Coursera_Capstone/blob/master/Copy_of_capstone_final_book.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **PART 1**

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# /bin/bash: conda: command not found
# /bin/bash: conda: command not found
# Folium installed
# Libraries imported.

# %% [markdown]
# Import Pandas

# %%
import pandas as pd
import numpy as np
import html5lib
from pandas import DataFrame

# %% [markdown]
# Two Calls to Fourswuare. One for coffee, one for hospitals.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
#import geopandas as gpd

# %%
CLIENT_ID = 'A143COJZJ5N1ZVY5Y3EY2NZOM2FFAHK4MZQBNT0SUAHYEKGD' # your Foursquare ID
CLIENT_SECRET = 'QVG5C0JSYHCLNKTCCBBOLBVLNGFPE15ZLVIEYWZUBRRKNIFZ' # your Foursquare Secret
VERSION = '20180604'

# %%
CLIENT_ID = 'A143COJZJ5N1ZVY5Y3EY2NZOM2FFAHK4MZQBNT0SUAHYEKGD' # your Foursquare ID
CLIENT_SECRET = 'QVG5C0JSYHCLNKTCCBBOLBVLNGFPE15ZLVIEYWZUBRRKNIFZ' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 140
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: A143COJZJ5N1ZVY5Y3EY2NZOM2FFAHK4MZQBNT0SUAHYEKGD
# CLIENT_SECRET:QVG5C0JSYHCLNKTCCBBOLBVLNGFPE15ZLVIEYWZUBRRKNIFZ

# %% [markdown]
# address is point park university as the center of pittsbugh (three rivers)

# %%
address = '201 Wood St, Pittsburgh, PA 15222'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.4385743 -80.0020058

# %% [markdown]
# use 5000 metres, about radius of pittsburgh

# %%
search_query = 'Coffee'
radius = 10000
print(search_query + ' .... OK!')
# Out:
# Coffee .... OK!

# %%
search_query2 = 'hospital'
radius2 = 10000
print(search_query2 + ' .... OK!')
# Out:
# hospital .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=A143COJZJ5N1ZVY5Y3EY2NZOM2FFAHK4MZQBNT0SUAHYEKGD&client_secret=QVG5C0JSYHCLNKTCCBBOLBVLNGFPE15ZLVIEYWZUBRRKNIFZ&ll=40.4385743,-80.0020058&v=20180604&query=Coffee&radius=10000&limit=140'

# %%
url2 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query2, radius2, LIMIT)
url2
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=A143COJZJ5N1ZVY5Y3EY2NZOM2FFAHK4MZQBNT0SUAHYEKGD&client_secret=QVG5C0JSYHCLNKTCCBBOLBVLNGFPE15ZLVIEYWZUBRRKNIFZ&ll=40.4385743,-80.0020058&v=20180604&query=hospital&radius=10000&limit=140'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e49acb8a2e538001b7d733e'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4bd19d80046076b017157271',
#     'location': {'address': '225 5th Ave',
#      'cc': 'US',
#      'city': 'Pittsburgh',
#      'country': 'United States',
#      'crossStreet': 'Btw Liberty Ave. & Wood St.',
#      'distance': 295,
#      'formattedAddress': ['225 5th Ave (Btw Liberty Ave. & Wood St.)',
#       'Pittsburgh, PA 15222',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.44111204385811,
#        'lng': -80.00099394922842}],
#      'lat': 40.44111204385811,
#      'lng': -80.00099394922842,
# ...

# %%
results2 = requests.get(url2).json()
results2
# Out:
# {'meta': {'code': 200, 'requestId': '5e49ac3a29ce6a001c662a16'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'primary': True,
#       'shortName': 'Medical'}],
#     'hasPerk': False,
#     'id': '4ad4c010f964a520b9ee20e3',
#     'location': {'address': '320 E North Ave',
#      'cc': 'US',
#      'city': 'Pittsburgh',
#      'country': 'United States',
#      'crossStreet': 'btwn Sandusky & James St',
#      'distance': 2044,
#      'formattedAddress': ['320 E North Ave (btwn Sandusky & James St)',
#       'Pittsburgh, PA 15212',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.45691707268496,
#        'lng': -80.00331228535038}],
#      'lat': 40.45691707268496,
#      'lng': -80.00331228535038,
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id  ... venuePage.id
# 0  4bd19d80046076b017157271  ...          NaN
# 1  4ad7b832f964a520070e21e3  ...          NaN
# 2  4e0dbf3b22711665f60d5a8b  ...     35495319
# 3  4b2a306bf964a520eba524e3  ...    102908164
# 4  5da0a00a7df9840008295523  ...          NaN
#
# [5 rows x 25 columns]

# %%
# assign relevant part of JSON to venues
venues2 = results2['response']['venues']

# tranform venues into a dataframe
dataframe2 = json_normalize(venues2)
dataframe2.head()
# Out:
#                          id  ... venuePage.id
# 0  4ad4c010f964a520b9ee20e3  ...          NaN
# 1  4ad4c010f964a520bdee20e3  ...          NaN
# 2  4b0180faf964a520f24222e3  ...          NaN
# 3  4b4dc9bbf964a520b5d726e3  ...          NaN
# 4  4b806d1ef964a520467130e3  ...          NaN
#
# [5 rows x 19 columns]

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                              name  ...                        id
# 0                      21st Street Coffee and Tea  ...  4bd19d80046076b017157271
# 1                   Nicholas Coffee & Tea Company  ...  4ad7b832f964a520070e21e3
# 2                                Delanie's Coffee  ...  4e0dbf3b22711665f60d5a8b
# 3                       Prestogeorge Coffee & Tea  ...  4b2a306bf964a520eba524e3
# 4                        Creative Coffee + Supply  ...  5da0a00a7df9840008295523
# 5                 Allegheny Coffee & Tea Exchange  ...  4a2aa088f964a5202b961fe3
# 6                         Adda Coffee & Tea House  ...  5c210b37d8096e0039daf177
# 7                            Coffee Tree Roasters  ...  45e041a6f964a52022431fe3
# 8                                     Coffee Shop  ...  4f32432419836c91c7c63ce0
# 9                                Fort Pitt Coffee  ...  58ee6754c960274628939615
# 10                     Gasoline Street Coffee Co.  ...  56a13dd3498ec8582aca92ef
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns2 = ['name', 'categories'] + [col for col in dataframe2.columns if col.startswith('location.')] + ['id']
dataframe_filtered2 = dataframe2.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered2['categories'] = dataframe_filtered2.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered2.columns = [column.split('.')[-1] for column in dataframe_filtered2.columns]

dataframe_filtered2
# Out:
#                                                  name  ...                        id
# 0                          Allegheny General Hospital  ...  4ad4c010f964a520b9ee20e3
# 1                      Magee-Women's Hospital of UPMC  ...  4ad4c010f964a520bdee20e3
# 2                       Western Pennsylvania Hospital  ...  4b0180faf964a520f24222e3
# 3           Children's Hospital of Pittsburgh of UPMC  ...  4b4dc9bbf964a520b5d726e3
# 4                                    Kindred Hospital  ...  4b806d1ef964a520467130e3
# 5                  Allegheny General Hospital Pick-up  ...  4c74ebda3adda1434bcf05af
# 6                                  St. Clair Hospital  ...  4ad4c010f964a520bfee20e3
# 7   Children’s Hospital of Pittsburgh of UPMC Outp...  ...  4d95d2f50caaa14306f666b3
# 8   Children's Hospital of Pittsburgh of UPMC Emer...  ...  4e258da345dd3b8cf8f9e48d
# 9   Bariatric Surgery at Magee-Womens Hospital of ...  ...  5123c3d77043471453057610
# ...

# %%
dataframe_filtered.name
# Out:
# 0                        21st Street Coffee and Tea
# 1                     Nicholas Coffee & Tea Company
# 2                                  Delanie's Coffee
# 3                         Prestogeorge Coffee & Tea
# 4                          Creative Coffee + Supply
# 5                   Allegheny Coffee & Tea Exchange
# 6                           Adda Coffee & Tea House
# 7                              Coffee Tree Roasters
# 8                                       Coffee Shop
# 9                                  Fort Pitt Coffee
# 10                       Gasoline Street Coffee Co.
# 11                                   Redhawk Coffee
# 12                          Rock 'n' Joe Coffee Bar
# 13                                Cool Beans Coffee
# 14                                  Coffee Ala Cart
# 15                Coffee Tree Roaster Rockwell Hall
# 16                  Quick Stop Convenience & Coffee
# 17                            The rockin coffee pot
# ...

# %%
#!pip install folium

# %% [markdown]
# Get pittsburgh neighborhood geodata
#
# from site http://pghgis-pittsburghpa.opendata.arcgis.com/datasets/dbd133a206cc4a3aa915cb28baa60fd4_0

# %%
pitt = pd.read_csv('http://pghgis-pittsburghpa.opendata.arcgis.com/datasets/3ca13246362540fa8b4b567f84a1255b_0.csv')

# %%
#pittcols = [col for col in pitt.columns if 'lat' in col]
print(list(pitt.columns))
# Out:
# ['OBJECTID', 'Neighborhood_2010_FID_BlockG', 'Neighborhood_2010_STATEFP10', 'Neighborhood_2010_COUNTYFP10', 'Neighborhood_2010_TRACTCE10', 'Neighborhood_2010_BLKGRPCE10', 'Neighborhood_2010_GEOID10', 'Neighborhood_2010_NAMELSAD10', 'Neighborhood_2010_MTFCC10', 'Neighborhood_2010_FUNCSTAT10', 'Neighborhood_2010_ALAND10', 'Neighborhood_2010_AWATER10', 'Neighborhood_2010_INTPTLAT10', 'Neighborhood_2010_INTPTLON10', 'Neighborhood_2010_Shape_Leng', 'Neighborhood_2010_FID_Neighb', 'Neighborhood_2010_AREA', 'Neighborhood_2010_PERIMETER', 'Neighborhood_2010_NEIGHBOR_', 'Neighborhood_2010_NEIGHBOR_I', 'Neighborhood_2010_HOOD', 'Neighborhood_2010_HOOD_NO', 'Neighborhood_2010_ACRES', 'Neighborhood_2010_SQMILES', 'Neighborhood_2010_DPWDIV', 'Neighborhood_2010_UNIQUE_ID', 'Neighborhood_2010_SECTORS', 'Neighborhood_2010_Shape_Le_1', 'Neighborhood_2010_Shape_Ar_1', 'Neighborhood_2010_Page_Number', 'SNAP_All_csv_Neighborhood', 'SNAP_All_csv_Sector__', 'Pop__1940', 'Pop__1950', 'Pop__1960', 'Pop__197
# ...

# %%
pitt.head()
# Out:
#    OBJECTID  ...  SNAP_All_csv_Work_at_Home__2010
# 0         1  ...                             1.2%
# 1         2  ...                             4.4%
# 2         3  ...                             0.0%
# 3         4  ...                             0.0%
# 4         5  ...                             9.0%
#
# [5 rows x 190 columns]

# %% [markdown]
# Make pitt dataframe into geodataframe

# %%
# !pip install geopandas
# Out:
# ...
#      |████████████████████████████████| 921kB 2.7MB/s
# ...
#      |████████████████████████████████| 10.1MB 49.5MB/s
# ...
#      |████████████████████████████████| 11.8MB 31.6MB/s
# ...

# %%
#help("modules")checked to see if modules are installed

# %%
import geopandas
from geopandas import GeoDataFrame
from shapely.geometry import Point, Polygon

# %%
# !pip3 install geojsonio==0.0.3
# Out:
# ...
#      |████████████████████████████████| 153kB 2.9MB/s
# ...
#      |████████████████████████████████| 81kB 10.0MB/s
# ...
#      |████████████████████████████████| 2.3MB 32.6MB/s
# ...
#   Created wheel for geojsonio: filename=geojsonio-0.0.3-cp36-none-any.whl size=5036 sha256=b4adacb7780a4022da6e92df514c6730e3e731720217562cf23af403e918e4b7
#   Stored in directory: /root/.cache/pip/wheels/a9/ef/7c/7bbf228825e8717adaa84cd4b6c4ed8649b7958dd2bac45076
# Successfully built geojsonio
# ...

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %% [markdown]
# ##left off here

# %%
pitt.head()
# Out:
#    OBJECTID  ...  SNAP_All_csv_Work_at_Home__2010
# 0         1  ...                             1.2%
# 1         2  ...                             4.4%
# 2         3  ...                             0.0%
# 3         4  ...                             0.0%
# 4         5  ...                             9.0%
#
# [5 rows x 190 columns]

# %% [markdown]
# help https://gis.stackexchange.com/questions/174159/convert-a-pandas-dataframe-to-a-geodataframe

# %%
gdf = geopandas.GeoDataFrame(pitt, geometry=geopandas.points_from_xy(x=pitt.Neighborhood_2010_INTPTLAT10, y=pitt.Neighborhood_2010_INTPTLON10))

# %%
import shapely
shapely.speedups.enable()

# %%
gdf.to_file("output.json", driver="GeoJSON")

# %%
gdf.crs = {'init': 'epsg:4326'}

# %%
gdf.dtypes
# Out:
# OBJECTID                              int64
# Neighborhood_2010_FID_BlockG          int64
# Neighborhood_2010_STATEFP10           int64
# Neighborhood_2010_COUNTYFP10          int64
# Neighborhood_2010_TRACTCE10           int64
#                                      ...
# SNAP_All_csv_Commute_to_Work__B      object
# SNAP_All_csv_Commute_to_Work__W      object
# SNAP_All_csv_Commute_to_Work__O      object
# SNAP_All_csv_Work_at_Home__2010      object
# geometry                           geometry
# Length: 191, dtype: object

# %%
gdf['Neighborhood_2010_HOOD']
# Out:
# 0          Central Oakland
# 1            North Oakland
# 2             West Oakland
# 3         Crawford-Roberts
# 4           Strip District
#               ...
# 85          Chartiers City
# 86               Ridgemont
# 87                West End
# 88    California-Kirkbride
# 89              Glen Hazel
# Name: Neighborhood_2010_HOOD, Length: 90, dtype: object

# %%
dataframe_filtered.head()
# Out:
#                             name  ...                        id
# 0     21st Street Coffee and Tea  ...  4bd19d80046076b017157271
# 1  Nicholas Coffee & Tea Company  ...  4ad7b832f964a520070e21e3
# 2               Delanie's Coffee  ...  4e0dbf3b22711665f60d5a8b
# 3      Prestogeorge Coffee & Tea  ...  4b2a306bf964a520eba524e3
# 4       Creative Coffee + Supply  ...  5da0a00a7df9840008295523
#
# [5 rows x 16 columns]

# %%
dataframe_filtered['neighborhood'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                           NaN
# 1     Fifth and Forbes Corridor
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                           NaN
# 7                           NaN
# 8                           NaN
# 9                           NaN
# 10                          NaN
# 11    Fifth and Forbes Corridor
# 12                          NaN
# 13                          NaN
# 14                          NaN
# 15                          NaN
# 16                          NaN
# 17                          NaN
# 18                          NaN
# 19                          NaN
# 20                          NaN
# 21                          NaN
# 22                          NaN
# 23                          NaN
# 24                          NaN
# 25                  Polish Hill
# 26                          NaN
# 27                          NaN
# ...

# %% [markdown]
# read this for help https://notebooks.ai/maticaputti/quick-guide-about-geospatial-data-using-geopandas-shapely-and-folium-ba79c2d9

# %%
##geompitt = gdf['Neighborhood_2010_HOOD','geometry'].copy()
##geompitt.head()

# %%
print(gdf['geometry'])
# Out:
# 0     POINT (40.44068 -79.95423)
# 1     POINT (40.44584 -79.94839)
# 2     POINT (40.44124 -79.96261)
# 3     POINT (40.44039 -79.98135)
# 4     POINT (40.45450 -79.98128)
#                  ...
# 85    POINT (40.45782 -80.07058)
# 86    POINT (40.42707 -80.03448)
# 87    POINT (40.44088 -80.03571)
# 88    POINT (40.45994 -80.02187)
# 89    POINT (40.40505 -79.93083)
# Name: geometry, Length: 90, dtype: geometry

# %%
gdf.head()
# Out:
#    OBJECTID  ...                    geometry
# 0         1  ...  POINT (40.44068 -79.95423)
# 1         2  ...  POINT (40.44584 -79.94839)
# 2         3  ...  POINT (40.44124 -79.96261)
# 3         4  ...  POINT (40.44039 -79.98135)
# 4         5  ...  POINT (40.45450 -79.98128)
#
# [5 rows x 191 columns]

# %%
gdf.columns
# Out:
# Index(['OBJECTID', 'Neighborhood_2010_FID_BlockG',
#        'Neighborhood_2010_STATEFP10', 'Neighborhood_2010_COUNTYFP10',
#        'Neighborhood_2010_TRACTCE10', 'Neighborhood_2010_BLKGRPCE10',
#        'Neighborhood_2010_GEOID10', 'Neighborhood_2010_NAMELSAD10',
#        'Neighborhood_2010_MTFCC10', 'Neighborhood_2010_FUNCSTAT10',
#        ...
#        'SNAP_All_csv_Commute_to_Work__D', 'SNAP_All_csv_Commute_to_Work__C',
#        'SNAP_All_csv_Commute_to_Work__P', 'SNAP_All_csv_Commute_to_Work__T',
#        'SNAP_All_csv_Commute_to_Work__M', 'SNAP_All_csv_Commute_to_Work__B',
#        'SNAP_All_csv_Commute_to_Work__W', 'SNAP_All_csv_Commute_to_Work__O',
#        'SNAP_All_csv_Work_at_Home__2010', 'geometry'],
#       dtype='object', length=191)

# %%
df1 = gdf.dropna(axis=1)
print(df1)
# Out:
#     OBJECTID  ...                    geometry
# 0          1  ...  POINT (40.44068 -79.95423)
# 1          2  ...  POINT (40.44584 -79.94839)
# 2          3  ...  POINT (40.44124 -79.96261)
# 3          4  ...  POINT (40.44039 -79.98135)
# 4          5  ...  POINT (40.45450 -79.98128)
# ..       ...  ...                         ...
# 85        86  ...  POINT (40.45782 -80.07058)
# 86        87  ...  POINT (40.42707 -80.03448)
# 87        88  ...  POINT (40.44088 -80.03571)
# 88        89  ...  POINT (40.45994 -80.02187)
# 89        90  ...  POINT (40.40505 -79.93083)
#
# [90 rows x 157 columns]

# %%
gdf.size
# Out:
# 17190

# %%
# !wget --quiet http://pghgis-pittsburghpa.opendata.arcgis.com/datasets/3ca13246362540fa8b4b567f84a1255b_0.geojson -O nhood.geojson
    
print('GeoJSON file downloaded!')
# Out:
# GeoJSON file downloaded!

# %%
pgeo= r'nhood.geojson'

# %% [markdown]
# # START HERE MAKE DROP NA ON POINTS

# %%
df1
# Out:
#     OBJECTID  ...                    geometry
# 0          1  ...  POINT (40.44068 -79.95423)
# 1          2  ...  POINT (40.44584 -79.94839)
# 2          3  ...  POINT (40.44124 -79.96261)
# 3          4  ...  POINT (40.44039 -79.98135)
# 4          5  ...  POINT (40.45450 -79.98128)
# ..       ...  ...                         ...
# 85        86  ...  POINT (40.45782 -80.07058)
# 86        87  ...  POINT (40.42707 -80.03448)
# 87        88  ...  POINT (40.44088 -80.03571)
# 88        89  ...  POINT (40.45994 -80.02187)
# 89        90  ...  POINT (40.40505 -79.93083)
#
# [90 rows x 157 columns]

# %%
import json
geojson_layer = folium.GeoJson(json.load(open('nhood.geojson')),
                               name='geojson')
gdf1 = geopandas.read_file('nhood.geojson')

# %%
venues_map = folium.Map(width=800,height=500, location=[latitude, longitude], tiles='Stamen Toner', zoom_start=11)


folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='CENTER',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the coffee shops as blue circle markers
for lat, lng, label in zip(gdf.Neighborhood_2010_INTPTLAT10, gdf.Neighborhood_2010_INTPTLON10, gdf.Neighborhood_2010_HOOD):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='green',
        popup=label,
        fill = True,
        fill_color='green',
        fill_opacity=0.6
    ).add_to(venues_map)

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.name):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

for lat, lng, label in zip(dataframe_filtered2.lat, dataframe_filtered2.lng, dataframe_filtered2.name):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='orange',
        popup=label,
        fill = True,
        fill_color='orange',
        fill_opacity=0.6
    ).add_to(venues_map)




# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
